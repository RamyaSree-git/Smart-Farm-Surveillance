# %%
# %cd .. 
# !git clone https://github.com/theAIGuysCode/yolov4-custom-functions.git
# Out:
# Cloning into 'yolov4-custom-functions'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 251 (delta 3), reused 0 (delta 0), pack-reused 241
# Receiving objects: 100% (251/251), 62.01 MiB | 43.40 MiB/s, done.
# Resolving deltas: 100% (116/116), done.

# %%
# %cd yolov4-custom-functions/
# Out:
# /content/yolov4-custom-functions/yolov4-custom-functions

# %%
! pip uninstall tensorflow
! pip install tensorflow==2.3.0
# Out:
# Found existing installation: tensorflow 2.8.0
# Uninstalling tensorflow-2.8.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#
#   Successfully uninstalled tensorflow-2.8.0
# ...
#      |████████████████████████████████| 320.4 MB 31 kB/s
# ...
#      |████████████████████████████████| 20.1 MB 56.6 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 50.5 MB/s
# ...
#      |████████████████████████████████| 459 kB 63.8 MB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# ...

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# %cd /content
# !mkdir drive
# %cd drive
# !mkdir MyDrive
# %cd ..
# %cd ..
# !google-drive-ocamlfuse /content/drive/MyDrive
# Out:
# E: Package 'python-software-properties' has no installation candidate

# %%
# !ln -s /content/drive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# ln: failed to create symbolic link '/mydrive/MyDrive': Software caused connection abort
# ls: cannot open directory '/mydrive': Transport endpoint is not connected

# %%
% cd /content/yolov4-custom-functions
# Out:
# /content/yolov4-custom-functions

# %%
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/backup/yolov4-obj_best.weights ./data
#!cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/yolov4_cow_class/data_backup/cow-weights/yolov4-obj_last.weights ./data

# %%
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/obj.names ./data/classes

# %%
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/cow2_sample.jpg ./data/images

# %%
! pip install pytesseract
# Out:
# ...
#      |████████████████████████████████| 4.3 MB 5.3 MB/s
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %% [markdown]
# Steps:
# 1. Change the save_model.py file with the custom weights
# 2. Change the config.py with the custome 'obj.names' files which has our custom classes

# %%
# Convert darknet weights to tensorflow model
# !python save_model.py --model yolov4
# Out:
# 2022-03-18 17:32:18.015380: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-18 17:32:20.160780: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-03-18 17:32:20.216237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-18 17:32:20.217252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2022-03-18 17:32:20.217294: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/Cow1_sample.jpg ./data/images
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/Cow3_sample.jpg ./data/images
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/Cow4_sample.jpg ./data/images
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/cow-6.jpg ./data/images
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/sheep-1.jpg ./data/images
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/sheep-2.jpg ./data/images
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/cow2_sample.jpg ./data/images

# %%
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/cow-sheep.jpg ./data/images

# %%
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/cow-sheep.jpg ./data/images
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/cow-sheep2.jpg ./data/images
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_image_sample/cow-sheep3.jpg ./data/images

# %%
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_videos/cow_video.mp4 ./data/video
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_videos/cow4.mov ./data/video
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_videos/cowtest.mov ./data/video
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_videos/cow2.mov ./data/video
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_videos/cow3.mp4 ./data/video

# %%
#!cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_videos/sheep1.mov ./data/video
# !cp /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/test_videos/cow2.mov ./data/video

# %%
# run DeepSort with YOLOv4 Object Detections as backbone (enable --info flag to see info about tracked objects)

# Run yolov4 model while counting total objects detected
# !python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --images ./data/images/cow-sheep.jpg --count
# Out:
# Traceback (most recent call last):
#   File "detect.py", line 146, in <module>
#     app.run(main)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 312, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 258, in _run_main
#     sys.exit(main(argv))
#   File "detect.py", line 49, in main
#     saved_model_loaded = tf.saved_model.load(FLAGS.weights, tags=[tag_constants.SERVING])
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/load.py", line 603, in load
#     return load_internal(export_dir, tags, options)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/load.py", line 614, in load_internal
#     loader_impl.parse_saved_model_with_debug_info(export_dir))
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py", line 56, in parse_saved_model_with_debug_info
#     saved_model = _parse_saved_model(export_dir)
# ...

# %%
# !python detect_video.py --weights ./checkpoints/yolov4-416 --model yolov4 --video ./data/video/cow_new_2.mp4 --output ./detections/result.avi --count
# Out:
# Number of Cows: 3
# FPS: 0.49
# Number of Cows: 3
# FPS: 30.74
# Number of Cows: 4
# FPS: 31.08
# Number of Cows: 4
# FPS: 30.48
# Number of Cows: 4
# FPS: 29.94
# Number of Cows: 4
# FPS: 30.95
# Number of Cows: 4
# FPS: 31.21
# Number of Cows: 4
# FPS: 31.48
# Number of Cows: 4
# FPS: 31.33
# Number of Cows: 4
# FPS: 30.68
# Number of Cows: 4
# FPS: 31.25
# Number of Cows: 4
# FPS: 31.55
# Number of Cows: 4
# FPS: 30.68
# Number of Cows: 4
# FPS: 31.41
# Number of Cows: 4
# FPS: 30.81
# Number of Cows: 4
# FPS: 30.94
# Number of Cows: 4
# FPS: 31.07
# Number of Cows: 4
# FPS: 31.37
# Number of Cows: 4
# FPS: 31.24
# Number of Cows: 4
# FPS: 31.51
# Number of Cows: 4
# FPS: 31.05
# Number of Cows: 4
# FPS: 31.02
# Number of Cows: 4
# FPS: 29.33
# Number of Cows: 4
# FPS: 30.63
# Number of Cows: 4
# FPS: 31.16
# Number of Cows: 4
# FPS: 31.36
# Number of Cows: 4
# FPS: 31.29
# Number of Cows: 4
# FPS: 31.06
# Number of Cows: 4
# FPS: 30.80
# Number of Cows: 4
# FPS: 30.75
# ...

# %%
# !cp ./detections/result.avi /content/drive/MyDrive/Sem4/DATA298B/Smart_Farm_Surveillance/Yolov4/output

# %%
# define helper function to display videos
import io 
from IPython.display import HTML
from base64 import b64encode
def show_video(file_name, width=640):
  # show resulting deepsort video
  mp4 = open(file_name,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
  </video>
  """.format(width, data_url))

# %%
# convert resulting video from avi to mp4 file format
import os
path_video = os.path.join("detections","result.avi")
# %cd /content/yolov4-custom-functions/detections/
# !ffmpeg -y -loglevel panic -i result.avi output.mp4
# %cd ..

# output object tracking video
path_output = os.path.join("detections","output.mp4")
show_video(path_output, width=960)
# Out:
# /content/yolov4-custom-functions/detections
# /content/yolov4-custom-functions
